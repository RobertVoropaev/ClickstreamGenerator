# %%
from ClickstreamGenerator import Clickstream_Generator

# %%
gen = Clickstream_Generator()

# %%
gen.clickstream
# Out:
# Empty DataFrame
# Columns: [user_id, session_id, event_type, event_page, timestamp]
# Index: []

# %%
gen.make_steps(1000)
# Out:
# start_new_user_session 61
# make_event_for_user 61
# increase_current_session 1 -> 2
# start_new_user_session 70
# make_new_page_for_user 61
# make_event_for_user 61
# make_error_for_user 70
# make_new_page_for_user 61
# increase_current_session 2 -> 3
# start_new_user_session 90
# stop_user_session 90
# start_new_user_session 28
# make_event_for_user 28
# stop_user_session 70
# make_error_for_user 61
# make_new_page_for_user 28
# make_event_for_user 28
# stop_user_session 28
# start_new_user_session 7
# make_event_for_user 61
# make_event_for_user 7
# make_error_for_user 61
# make_error_for_user 61
# stop_user_session 7
# make_event_for_user 61
# start_new_user_session 41
# start_new_user_session 38
# make_error_for_user 41
# increase_current_session 3 -> 4
# make_error_for_user 61
# make_new_page_for_user 41
# stop_user_session 38
# make_event_for_user 41
# make_new_page_for_user 41
# make_error_for_user 61
# make_event_for_user 41
# start_new_user_session 48
# ...

# %%
gen.clickstream[gen.clickstream.user_id == 1].sort_values(["user_id", "timestamp"])
# Out:
#     user_id session_id          event_type  event_page   timestamp
# 39        1         14                page        main  1618521767
# 40        1         14  VFuFerrorQTnmqQcDB        main  1618521767
# 41        1         14                page      salary  1618521777
# 326       1        101                page        main  1618523849
# 328       1        101     qKCwAmlgerrorTD        main  1618523860
# 329       1        101                page   id-center  1618523868
# 333       1        101                page  smsinfooct  1618523884
# 393       1        115                page        main  1618524337

# %%
random.choice([1, 2, 3])
# Out:
# 2
